# %%
import requests
url = "https://api.coingecko.com/api/v3/coins/markets"

# %%
all_data = []

for page in range(1, 7):
    response = requests.get(url, params= {
        "vs_currency": "usd",
        "order": "market_cap_desc",
        "per_page": 100,
        "page": page,
    })
    data = response.json()
    
    if isinstance(data, list):
        all_data.extend(data)

# %%
all_data
# Out:
# [{'id': 'bitcoin',
#   'symbol': 'btc',
#   'name': 'Bitcoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/1/large/bitcoin.png?1696501400',
#   'current_price': 77224,
#   'market_cap': 1545460597452,
#   'market_cap_rank': 1,
#   'fully_diluted_valuation': 1545461832760,
#   'total_volume': 59745164297,
#   'high_24h': 78240,
#   'low_24h': 74419,
#   'price_change_24h': 2804.63,
#   'price_change_percentage_24h': 3.7687,
#   'market_cap_change_24h': 56174647880,
#   'market_cap_change_percentage_24h': 3.77192,
#   'circulating_supply': 20017171.0,
#   'total_supply': 20017187.0,
#   'max_supply': 21000000.0,
#   'ath': 126080,
#   'ath_change_percentage': -38.75027,
#   'ath_date': '2025-10-06T18:57:42.558Z',
#   'atl': 67.81,
#   'atl_change_percentage': 113783.97804,
#   'atl_date': '2013-07-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:57.798Z'},
#  {'id': 'ethereum',
#   'symbol': 'eth',
#   'name': 'Ethereum',
#   'image': 'https://coin-images.coingecko.com/coins/images/279/large/ethereum.png?1696501628',
#   'current_price': 2423.59,
#   'market_cap': 292370944641,
#   'market_cap_rank': 2,
#   'fully_diluted_valuation': 292370944641,
#   'total_volume': 25198443412,
#   'high_24h': 2462.81,
#   'low_24h': 2319.42,
#   'price_change_24h': 95.59,
#   'price_change_percentage_24h': 4.10618,
#   'market_cap_change_24h': 11546719136,
#   'market_cap_change_percentage_24h': 4.11172,
#   'circulating_supply': 120690898.2892637,
#   'total_supply': 120690898.2892637,
#   'max_supply': None,
#   'ath': 4946.05,
#   'ath_change_percentage': -50.99942,
#   'ath_date': '2025-08-24T19:21:03.333Z',
#   'atl': 0.432979,
#   'atl_change_percentage': 559648.38677,
#   'atl_date': '2015-10-20T00:00:00.000Z',
#   'roi': {'times': 40.97647849225858,
#    'currency': 'btc',
#    'percentage': 4097.6478492258575},
#   'last_updated': '2026-04-17T18:33:57.888Z'},
#  {'id': 'tether',
#   'symbol': 'usdt',
#   'name': 'Tether',
#   'image': 'https://coin-images.coingecko.com/coins/images/325/large/Tether.png?1696501661',
#   'current_price': 1.0,
#   'market_cap': 185873878309,
#   'market_cap_rank': 3,
#   'fully_diluted_valuation': 191342727115,
#   'total_volume': 99258321265,
#   'high_24h': 1.0,
#   'low_24h': 1.0,
#   'price_change_24h': 0.0001563,
#   'price_change_percentage_24h': 0.01563,
#   'market_cap_change_24h': 103109586,
#   'market_cap_change_percentage_24h': 0.0555,
#   'circulating_supply': 185809000661.4175,
#   'total_supply': 191275940613.3962,
#   'max_supply': None,
#   'ath': 1.32,
#   'ath_change_percentage': -24.39553,
#   'ath_date': '2018-07-24T00:00:00.000Z',
#   'atl': 0.572521,
#   'atl_change_percentage': 74.72184,
#   'atl_date': '2015-03-02T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:57.842Z'},
#  {'id': 'ripple',
#   'symbol': 'xrp',
#   'name': 'XRP',
#   'image': 'https://coin-images.coingecko.com/coins/images/44/large/xrp-symbol-white-128.png?1696501442',
#   'current_price': 1.48,
#   'market_cap': 91086540096,
#   'market_cap_rank': 4,
#   'fully_diluted_valuation': 147919390223,
#   'total_volume': 4476653832,
#   'high_24h': 1.51,
#   'low_24h': 1.42,
#   'price_change_24h': 0.04363607,
#   'price_change_percentage_24h': 3.0422,
#   'market_cap_change_24h': 2831448678,
#   'market_cap_change_percentage_24h': 3.20826,
#   'circulating_supply': 61569680267.0,
#   'total_supply': 99985679023.0,
#   'max_supply': 100000000000.0,
#   'ath': 3.65,
#   'ath_change_percentage': -59.4667,
#   'ath_date': '2025-07-18T03:40:53.808Z',
#   'atl': 0.00268621,
#   'atl_change_percentage': 54921.72538,
#   'atl_date': '2014-05-22T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:57.495Z'},
#  {'id': 'binancecoin',
#   'symbol': 'bnb',
#   'name': 'BNB',
#   'image': 'https://coin-images.coingecko.com/coins/images/825/large/bnb-icon2_2x.png?1696501970',
#   'current_price': 639.94,
#   'market_cap': 86224049098,
#   'market_cap_rank': 5,
#   'fully_diluted_valuation': 86224048554,
#   'total_volume': 1515208533,
#   'high_24h': 645.76,
#   'low_24h': 627.24,
#   'price_change_24h': 9.41,
#   'price_change_percentage_24h': 1.49161,
#   'market_cap_change_24h': 1276947546,
#   'market_cap_change_percentage_24h': 1.50323,
#   'circulating_supply': 134786764.7,
#   'total_supply': 134786763.85,
#   'max_supply': 200000000.0,
#   'ath': 1369.99,
#   'ath_change_percentage': -53.28875,
#   'ath_date': '2025-10-13T08:41:24.131Z',
#   'atl': 0.0398177,
#   'atl_change_percentage': 1607075.15742,
#   'atl_date': '2017-10-19T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:58.044Z'},
#  {'id': 'usd-coin',
#   'symbol': 'usdc',
#   'name': 'USDC',
#   'image': 'https://coin-images.coingecko.com/coins/images/6319/large/USDC.png?1769615602',
#   'current_price': 0.999935,
#   'market_cap': 78600440457,
#   'market_cap_rank': 6,
#   'fully_diluted_valuation': 78627480408,
#   'total_volume': 21632845981,
#   'high_24h': 1.0,
#   'low_24h': 0.998646,
#   'price_change_24h': 7.592e-05,
#   'price_change_percentage_24h': 0.00759,
#   'market_cap_change_24h': -17296858.193756104,
#   'market_cap_change_percentage_24h': -0.022,
#   'circulating_supply': 78608162629.75993,
#   'total_supply': 78635205237.66826,
#   'max_supply': None,
#   'ath': 1.043,
#   'ath_change_percentage': -4.173,
#   'ath_date': '2018-11-15T00:00:00.000Z',
#   'atl': 0.877647,
#   'atl_change_percentage': 13.93206,
#   'atl_date': '2023-03-11T08:02:13.981Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:57.855Z'},
#  {'id': 'solana',
#   'symbol': 'sol',
#   'name': 'Solana',
#   'image': 'https://coin-images.coingecko.com/coins/images/4128/large/solana.png?1718769756',
#   'current_price': 89.08,
#   'market_cap': 51300662575,
#   'market_cap_rank': 7,
#   'fully_diluted_valuation': 55693585070,
#   'total_volume': 6756607223,
#   'high_24h': 90.46,
#   'low_24h': 87.33,
#   'price_change_24h': 1.74,
#   'price_change_percentage_24h': 1.99338,
#   'market_cap_change_24h': 1154092575,
#   'market_cap_change_percentage_24h': 2.30144,
#   'circulating_supply': 575380938.9220272,
#   'total_supply': 624651333.1657138,
#   'max_supply': None,
#   'ath': 293.31,
#   'ath_change_percentage': -69.63126,
#   'ath_date': '2025-01-19T11:15:27.957Z',
#   'atl': 0.500801,
#   'atl_change_percentage': 17686.5253,
#   'atl_date': '2020-05-11T19:35:23.449Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:57.326Z'},
#  {'id': 'tron',
#   'symbol': 'trx',
#   'name': 'TRON',
#   'image': 'https://coin-images.coingecko.com/coins/images/1094/large/photo_2026-04-13_09-59-16.png?1776048311',
#   'current_price': 0.326787,
#   'market_cap': 30971048029,
#   'market_cap_rank': 8,
#   'fully_diluted_valuation': 30971047025,
#   'total_volume': 577951051,
#   'high_24h': 0.327332,
#   'low_24h': 0.323496,
#   'price_change_24h': 0.00052427,
#   'price_change_percentage_24h': 0.16069,
#   'market_cap_change_24h': 51448485,
#   'market_cap_change_percentage_24h': 0.16639,
#   'circulating_supply': 94774635959.9303,
#   'total_supply': 94774632886.58519,
#   'max_supply': None,
#   'ath': 0.431288,
#   'ath_change_percentage': -24.22994,
#   'ath_date': '2024-12-04T00:10:40.323Z',
#   'atl': 0.00180434,
#   'atl_change_percentage': 18011.17236,
#   'atl_date': '2017-11-12T00:00:00.000Z',
#   'roi': {'times': 170.99338070229047,
#    'currency': 'usd',
#    'percentage': 17099.33807022905},
#   'last_updated': '2026-04-17T18:33:42.592Z'},
#  {'id': 'figure-heloc',
#   'symbol': 'figr_heloc',
#   'name': 'Figure Heloc',
#   'image': 'https://coin-images.coingecko.com/coins/images/68480/large/figure.png?1755863954',
#   'current_price': 1.037,
#   'market_cap': 17337346632,
#   'market_cap_rank': 9,
#   'fully_diluted_valuation': 17337346632,
#   'total_volume': 8519064,
#   'high_24h': 1.037,
#   'low_24h': 1.023,
#   'price_change_24h': 0.0073782,
#   'price_change_percentage_24h': 0.71684,
#   'market_cap_change_24h': 33029354,
#   'market_cap_change_percentage_24h': 0.19087,
#   'circulating_supply': 16720458685.507,
#   'total_supply': 16720458685.507,
#   'max_supply': None,
#   'ath': 1.049,
#   'ath_change_percentage': -1.16521,
#   'ath_date': '2026-03-09T17:00:25.937Z',
#   'atl': 0.155357,
#   'atl_change_percentage': 567.42848,
#   'atl_date': '2025-10-31T14:27:24.456Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:46.553Z'},
#  {'id': 'dogecoin',
#   'symbol': 'doge',
#   'name': 'Dogecoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/5/large/dogecoin.png?1696501409',
#   'current_price': 0.100076,
#   'market_cap': 15391161200,
#   'market_cap_rank': 10,
#   'fully_diluted_valuation': 16962808785,
#   'total_volume': 2804341803,
#   'high_24h': 0.102006,
#   'low_24h': 0.096768,
#   'price_change_24h': 0.0020051,
#   'price_change_percentage_24h': 2.04454,
#   'market_cap_change_24h': 288576137,
#   'market_cap_change_percentage_24h': 1.91077,
#   'circulating_supply': 153870196383.7052,
#   'total_supply': 169582443126.5791,
#   'max_supply': None,
#   'ath': 0.731578,
#   'ath_change_percentage': -86.32049,
#   'ath_date': '2021-05-08T05:08:23.458Z',
#   'atl': 8.69e-05,
#   'atl_change_percentage': 115057.60383,
#   'atl_date': '2015-05-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:45.310Z'},
#  {'id': 'whitebit',
#   'symbol': 'wbt',
#   'name': 'WhiteBIT Coin',
#   'image': 'https://coin-images.coingecko.com/coins/images/27045/large/wbt_token.png?1696526096',
#   'current_price': 56.16,
#   'market_cap': 11984721701,
#   'market_cap_rank': 11,
#   'fully_diluted_valuation': 17947845985,
#   'total_volume': 85838430,
#   'high_24h': 56.9,
#   'low_24h': 54.33,
#   'price_change_24h': 1.83,
#   'price_change_percentage_24h': 3.36326,
#   'market_cap_change_24h': 392989907,
#   'market_cap_change_percentage_24h': 3.39026,
#   'circulating_supply': 213418274.0,
#   'total_supply': 319606780.0,
#   'max_supply': 400000000.0,
#   'ath': 64.11,
#   'ath_change_percentage': -12.41498,
#   'ath_date': '2025-12-10T20:16:13.582Z',
#   'atl': 3.06,
#   'atl_change_percentage': 1733.8551,
#   'atl_date': '2023-02-13T19:01:21.899Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:43.508Z'},
#  {'id': 'usds',
#   'symbol': 'usds',
#   'name': 'USDS',
#   'image': 'https://coin-images.coingecko.com/coins/images/39926/large/usds.webp?1726666683',
#   'current_price': 0.999858,
#   'market_cap': 11387590778,
#   'market_cap_rank': 12,
#   'fully_diluted_valuation': 11387590778,
#   'total_volume': 57283909,
#   'high_24h': 1.0,
#   'low_24h': 0.999509,
#   'price_change_24h': -7.3250985982987e-05,
#   'price_change_percentage_24h': -0.00733,
#   'market_cap_change_24h': 23644242,
#   'market_cap_change_percentage_24h': 0.20806,
#   'circulating_supply': 11389388526.59124,
#   'total_supply': 11389388526.59124,
#   'max_supply': None,
#   'ath': 1.15,
#   'ath_change_percentage': -13.22056,
#   'ath_date': '2026-04-02T07:21:14.655Z',
#   'atl': 0.948265,
#   'atl_change_percentage': 5.43211,
#   'atl_date': '2024-10-03T13:19:28.826Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:54.072Z'},
#  {'id': 'hyperliquid',
#   'symbol': 'hype',
#   'name': 'Hyperliquid',
#   'image': 'https://coin-images.coingecko.com/coins/images/50882/large/hyperliquid.jpg?1729431300',
#   'current_price': 44.42,
#   'market_cap': 10576620256,
#   'market_cap_rank': 13,
#   'fully_diluted_valuation': 42693934172,
#   'total_volume': 345591419,
#   'high_24h': 45.46,
#   'low_24h': 43.24,
#   'price_change_24h': 0.841203,
#   'price_change_percentage_24h': 1.93029,
#   'market_cap_change_24h': 175188390,
#   'market_cap_change_percentage_24h': 1.68427,
#   'circulating_supply': 238385315.9541414,
#   'total_supply': 962274028.9541414,
#   'max_supply': 1000000000.0,
#   'ath': 59.3,
#   'ath_change_percentage': -25.09685,
#   'ath_date': '2025-09-18T03:30:30.650Z',
#   'atl': 3.81,
#   'atl_change_percentage': 1066.27292,
#   'atl_date': '2024-11-29T09:30:30.871Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:45.651Z'},
#  {'id': 'cardano',
#   'symbol': 'ada',
#   'name': 'Cardano',
#   'image': 'https://coin-images.coingecko.com/coins/images/975/large/cardano.png?1696502090',
#   'current_price': 0.261451,
#   'market_cap': 9662472463,
#   'market_cap_rank': 14,
#   'fully_diluted_valuation': 11766026793,
#   'total_volume': 696268056,
#   'high_24h': 0.266982,
#   'low_24h': 0.252418,
#   'price_change_24h': 0.00656834,
#   'price_change_percentage_24h': 2.57701,
#   'market_cap_change_24h': 219621531,
#   'market_cap_change_percentage_24h': 2.3258,
#   'circulating_supply': 36954807980.68808,
#   'total_supply': 45000000000.0,
#   'max_supply': 45000000000.0,
#   'ath': 3.09,
#   'ath_change_percentage': -91.53035,
#   'ath_date': '2021-09-02T06:00:10.474Z',
#   'atl': 0.01925275,
#   'atl_change_percentage': 1257.99134,
#   'atl_date': '2020-03-13T02:22:55.044Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:47.724Z'},
#  {'id': 'leo-token',
#   'symbol': 'leo',
#   'name': 'LEO Token',
#   'image': 'https://coin-images.coingecko.com/coins/images/8418/large/leo-token.png?1696508607',
#   'current_price': 10.13,
#   'market_cap': 9330317849,
#   'market_cap_rank': 15,
#   'fully_diluted_valuation': 9983044025,
#   'total_volume': 495343,
#   'high_24h': 10.21,
#   'low_24h': 10.04,
#   'price_change_24h': -0.057504284980195663,
#   'price_change_percentage_24h': -0.56431,
#   'market_cap_change_24h': -52797718.4185524,
#   'market_cap_change_percentage_24h': -0.56269,
#   'circulating_supply': 920821114.9,
#   'total_supply': 985239504.0,
#   'max_supply': None,
#   'ath': 10.25,
#   'ath_change_percentage': -1.14558,
#   'ath_date': '2026-04-16T13:15:10.538Z',
#   'atl': 0.799859,
#   'atl_change_percentage': 1166.75879,
#   'atl_date': '2019-12-24T15:14:35.376Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:47.376Z'},
#  {'id': 'bitcoin-cash',
#   'symbol': 'bch',
#   'name': 'Bitcoin Cash',
#   'image': 'https://coin-images.coingecko.com/coins/images/780/large/bitcoin-cash-circle.png?1696501932',
#   'current_price': 454.43,
#   'market_cap': 9099008515,
#   'market_cap_rank': 16,
#   'fully_diluted_valuation': 9099008515,
#   'total_volume': 270927623,
#   'high_24h': 461.12,
#   'low_24h': 440.79,
#   'price_change_24h': 13.64,
#   'price_change_percentage_24h': 3.09471,
#   'market_cap_change_24h': 276558381,
#   'market_cap_change_percentage_24h': 3.13471,
#   'circulating_supply': 20022768.64665078,
#   'total_supply': 20022768.64665078,
#   'max_supply': 21000000.0,
#   'ath': 3785.82,
#   'ath_change_percentage': -87.99655,
#   'ath_date': '2017-12-20T00:00:00.000Z',
#   'atl': 76.93,
#   'atl_change_percentage': 490.66761,
#   'atl_date': '2018-12-16T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:47.578Z'},
#  {'id': 'chainlink',
#   'symbol': 'link',
#   'name': 'Chainlink',
#   'image': 'https://coin-images.coingecko.com/coins/images/877/large/Chainlink_Logo_500.png?1760023405',
#   'current_price': 9.65,
#   'market_cap': 7016654916,
#   'market_cap_rank': 17,
#   'fully_diluted_valuation': 9650192822,
#   'total_volume': 452562417,
#   'high_24h': 9.84,
#   'low_24h': 9.35,
#   'price_change_24h': 0.22413,
#   'price_change_percentage_24h': 2.37733,
#   'market_cap_change_24h': 156454772,
#   'market_cap_change_percentage_24h': 2.28062,
#   'circulating_supply': 727099970.4523476,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 52.7,
#   'ath_change_percentage': -81.68388,
#   'ath_date': '2021-05-10T00:13:57.214Z',
#   'atl': 0.148183,
#   'atl_change_percentage': 6413.541,
#   'atl_date': '2017-11-29T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:47.742Z'},
#  {'id': 'memecore',
#   'symbol': 'm',
#   'name': 'MemeCore',
#   'image': 'https://coin-images.coingecko.com/coins/images/53247/large/square-bg-transparent.png?1752637478',
#   'current_price': 3.84,
#   'market_cap': 6752261882,
#   'market_cap_rank': 18,
#   'fully_diluted_valuation': 20574387106,
#   'total_volume': 17458503,
#   'high_24h': 3.87,
#   'low_24h': 3.59,
#   'price_change_24h': 0.229331,
#   'price_change_percentage_24h': 6.35889,
#   'market_cap_change_24h': 389141009,
#   'market_cap_change_percentage_24h': 6.11557,
#   'circulating_supply': 1758632501.18733,
#   'total_supply': 5358617081.050776,
#   'max_supply': 10000000000.0,
#   'ath': 3.87,
#   'ath_change_percentage': -0.63474,
#   'ath_date': '2026-04-17T13:35:23.985Z',
#   'atl': 0.04746135,
#   'atl_change_percentage': 7995.12994,
#   'atl_date': '2025-07-04T03:56:17.448Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:45.411Z'},
#  {'id': 'monero',
#   'symbol': 'xmr',
#   'name': 'Monero',
#   'image': 'https://coin-images.coingecko.com/coins/images/69/large/monero_logo.png?1696501460',
#   'current_price': 349.0,
#   'market_cap': 6438633681,
#   'market_cap_rank': 19,
#   'fully_diluted_valuation': 6438633681,
#   'total_volume': 126808150,
#   'high_24h': 354.13,
#   'low_24h': 341.32,
#   'price_change_24h': 3.74,
#   'price_change_percentage_24h': 1.08388,
#   'market_cap_change_24h': 72288858,
#   'market_cap_change_percentage_24h': 1.13548,
#   'circulating_supply': 18446744.07370955,
#   'total_supply': 18446744.07370955,
#   'max_supply': None,
#   'ath': 797.73,
#   'ath_change_percentage': -56.25065,
#   'ath_date': '2026-01-14T19:34:07.049Z',
#   'atl': 0.216177,
#   'atl_change_percentage': 161343.79705,
#   'atl_date': '2015-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:46.854Z'},
#  {'id': 'ethena-usde',
#   'symbol': 'usde',
#   'name': 'Ethena USDe',
#   'image': 'https://coin-images.coingecko.com/coins/images/33613/large/usde.png?1733810059',
#   'current_price': 0.999904,
#   'market_cap': 5831850223,
#   'market_cap_rank': 20,
#   'fully_diluted_valuation': 5831850223,
#   'total_volume': 78186880,
#   'high_24h': 1.0,
#   'low_24h': 0.999502,
#   'price_change_24h': 8.9e-06,
#   'price_change_percentage_24h': 0.00089,
#   'market_cap_change_24h': 2117023,
#   'market_cap_change_percentage_24h': 0.03631,
#   'circulating_supply': 5832209593.011188,
#   'total_supply': 5832209593.011188,
#   'max_supply': None,
#   'ath': 1.034,
#   'ath_change_percentage': -3.28364,
#   'ath_date': '2025-12-09T17:10:12.652Z',
#   'atl': 0.929486,
#   'atl_change_percentage': 7.5939,
#   'atl_date': '2024-10-04T07:57:15.809Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:54.501Z'},
#  {'id': 'canton-network',
#   'symbol': 'cc',
#   'name': 'Canton',
#   'image': 'https://coin-images.coingecko.com/coins/images/70468/large/Canton-Ticker_%281%29.png?1762826299',
#   'current_price': 0.150715,
#   'market_cap': 5770780550,
#   'market_cap_rank': 21,
#   'fully_diluted_valuation': 5770780550,
#   'total_volume': 10189794,
#   'high_24h': 0.152779,
#   'low_24h': 0.146935,
#   'price_change_24h': 0.00214202,
#   'price_change_percentage_24h': 1.44172,
#   'market_cap_change_24h': 81514518,
#   'market_cap_change_percentage_24h': 1.43278,
#   'circulating_supply': 38326859280.81231,
#   'total_supply': 38326859280.81231,
#   'max_supply': None,
#   'ath': 0.194152,
#   'ath_change_percentage': -22.34743,
#   'ath_date': '2026-02-03T08:02:08.411Z',
#   'atl': 0.059024,
#   'atl_change_percentage': 155.42767,
#   'atl_date': '2025-12-06T10:32:09.784Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:47.045Z'},
#  {'id': 'stellar',
#   'symbol': 'xlm',
#   'name': 'Stellar',
#   'image': 'https://coin-images.coingecko.com/coins/images/100/large/fmpFRHHQ_400x400.jpg?1735231350',
#   'current_price': 0.173063,
#   'market_cap': 5734805175,
#   'market_cap_rank': 22,
#   'fully_diluted_valuation': 8648901795,
#   'total_volume': 153616918,
#   'high_24h': 0.176864,
#   'low_24h': 0.164478,
#   'price_change_24h': 0.007466,
#   'price_change_percentage_24h': 4.50853,
#   'market_cap_change_24h': 246057633,
#   'market_cap_change_percentage_24h': 4.48295,
#   'circulating_supply': 33154556831.69474,
#   'total_supply': 50001786868.73495,
#   'max_supply': None,
#   'ath': 0.875563,
#   'ath_change_percentage': -80.25811,
#   'ath_date': '2018-01-03T00:00:00.000Z',
#   'atl': 0.00047612,
#   'atl_change_percentage': 36204.1832,
#   'atl_date': '2015-03-05T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:43.348Z'},
#  {'id': 'zcash',
#   'symbol': 'zec',
#   'name': 'Zcash',
#   'image': 'https://coin-images.coingecko.com/coins/images/486/large/circle-zcash-color.png?1696501740',
#   'current_price': 332.33,
#   'market_cap': 5539285900,
#   'market_cap_rank': 23,
#   'fully_diluted_valuation': 5539368486,
#   'total_volume': 364872955,
#   'high_24h': 353.91,
#   'low_24h': 330.12,
#   'price_change_24h': -4.111049097629291,
#   'price_change_percentage_24h': -1.22191,
#   'market_cap_change_24h': -69240859.69094372,
#   'market_cap_change_percentage_24h': -1.23456,
#   'circulating_supply': 16663459.5405448,
#   'total_supply': 16663707.9780448,
#   'max_supply': 21000000.0,
#   'ath': 3191.93,
#   'ath_change_percentage': -89.58834,
#   'ath_date': '2016-10-29T00:00:00.000Z',
#   'atl': 16.08,
#   'atl_change_percentage': 1966.72895,
#   'atl_date': '2024-07-05T04:22:29.321Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:45.684Z'},
#  {'id': 'ravedao',
#   'symbol': 'rave',
#   'name': 'RaveDAO',
#   'image': 'https://coin-images.coingecko.com/coins/images/70544/large/coin.jpeg?1762452940',
#   'current_price': 21.02,
#   'market_cap': 5228442771,
#   'market_cap_rank': 24,
#   'fully_diluted_valuation': 21078653030,
#   'total_volume': 262974579,
#   'high_24h': 21.75,
#   'low_24h': 15.88,
#   'price_change_24h': 4.65,
#   'price_change_percentage_24h': 28.37227,
#   'market_cap_change_24h': 1165379724,
#   'market_cap_change_percentage_24h': 28.68229,
#   'circulating_supply': 248044444.0,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 21.75,
#   'ath_change_percentage': -2.94305,
#   'ath_date': '2026-04-17T16:25:09.235Z',
#   'atl': 0.206266,
#   'atl_change_percentage': 10132.94078,
#   'atl_date': '2026-03-12T02:10:18.440Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:47.160Z'},
#  {'id': 'litecoin',
#   'symbol': 'ltc',
#   'name': 'Litecoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/2/large/litecoin.png?1696501400',
#   'current_price': 56.52,
#   'market_cap': 4353011138,
#   'market_cap_rank': 25,
#   'fully_diluted_valuation': 4353048910,
#   'total_volume': 438983668,
#   'high_24h': 57.31,
#   'low_24h': 55.4,
#   'price_change_24h': 0.556294,
#   'price_change_percentage_24h': 0.99401,
#   'market_cap_change_24h': 41082525,
#   'market_cap_change_percentage_24h': 0.95276,
#   'circulating_supply': 77070076.98347135,
#   'total_supply': 77070745.73347135,
#   'max_supply': 84000000.0,
#   'ath': 410.26,
#   'ath_change_percentage': -86.24467,
#   'ath_date': '2021-05-10T03:13:07.904Z',
#   'atl': 1.15,
#   'atl_change_percentage': 4812.12795,
#   'atl_date': '2015-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:43.465Z'},
#  {'id': 'dai',
#   'symbol': 'dai',
#   'name': 'Dai',
#   'image': 'https://coin-images.coingecko.com/coins/images/9956/large/Badge_Dai.png?1696509996',
#   'current_price': 0.999901,
#   'market_cap': 4343328049,
#   'market_cap_rank': 26,
#   'fully_diluted_valuation': 4343328049,
#   'total_volume': 31663369,
#   'high_24h': 1.0,
#   'low_24h': 0.99891,
#   'price_change_24h': -0.000102863221467575,
#   'price_change_percentage_24h': -0.01029,
#   'market_cap_change_24h': 14639837,
#   'market_cap_change_percentage_24h': 0.3382,
#   'circulating_supply': 4346276105.816092,
#   'total_supply': 4346276105.816092,
#   'max_supply': None,
#   'ath': 1.22,
#   'ath_change_percentage': -17.96712,
#   'ath_date': '2020-03-13T03:02:50.373Z',
#   'atl': 0.88196,
#   'atl_change_percentage': 13.3752,
#   'atl_date': '2023-03-11T07:50:50.514Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:47.592Z'},
#  {'id': 'avalanche-2',
#   'symbol': 'avax',
#   'name': 'Avalanche',
#   'image': 'https://coin-images.coingecko.com/coins/images/12559/large/Avalanche_Circle_RedWhite_Trans.png?1696512369',
#   'current_price': 9.78,
#   'market_cap': 4224167883,
#   'market_cap_rank': 27,
#   'fully_diluted_valuation': 4533997161,
#   'total_volume': 438951067,
#   'high_24h': 9.97,
#   'low_24h': 9.46,
#   'price_change_24h': 0.191478,
#   'price_change_percentage_24h': 1.99633,
#   'market_cap_change_24h': 89509158,
#   'market_cap_change_percentage_24h': 2.16485,
#   'circulating_supply': 431771961.1772119,
#   'total_supply': 463441061.1772119,
#   'max_supply': 720000000.0,
#   'ath': 144.96,
#   'ath_change_percentage': -93.26503,
#   'ath_date': '2021-11-21T14:18:56.538Z',
#   'atl': 2.8,
#   'atl_change_percentage': 248.54952,
#   'atl_date': '2020-12-31T13:15:21.540Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:54.967Z'},
#  {'id': 'usd1-wlfi',
#   'symbol': 'usd1',
#   'name': 'USD1',
#   'image': 'https://coin-images.coingecko.com/coins/images/54977/large/USD1_1000x1000_transparent.png?1749297002',
#   'current_price': 1.0,
#   'market_cap': 4174792260,
#   'market_cap_rank': 28,
#   'fully_diluted_valuation': 4184791912,
#   'total_volume': 1440800971,
#   'high_24h': 1.001,
#   'low_24h': 0.999412,
#   'price_change_24h': 0.0001206,
#   'price_change_percentage_24h': 0.01206,
#   'market_cap_change_24h': 65177625,
#   'market_cap_change_percentage_24h': 1.58598,
#   'circulating_supply': 4173684973.96984,
#   'total_supply': 4183681973.96984,
#   'max_supply': None,
#   'ath': 1.025,
#   'ath_change_percentage': -2.40337,
#   'ath_date': '2025-05-12T12:36:39.412Z',
#   'atl': 0.989633,
#   'atl_change_percentage': 1.06736,
#   'atl_date': '2025-10-01T08:51:32.103Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:46.139Z'},
#  {'id': 'paypal-usd',
#   'symbol': 'pyusd',
#   'name': 'PayPal USD',
#   'image': 'https://coin-images.coingecko.com/coins/images/31212/large/PYUSD_Token_Logo_2x.png?1765987788',
#   'current_price': 0.999872,
#   'market_cap': 4117957890,
#   'market_cap_rank': 29,
#   'fully_diluted_valuation': 4117957890,
#   'total_volume': 124594369,
#   'high_24h': 1.0,
#   'low_24h': 0.999583,
#   'price_change_24h': 6.54e-06,
#   'price_change_percentage_24h': 0.00065,
#   'market_cap_change_24h': 6624252,
#   'market_cap_change_percentage_24h': 0.16112,
#   'circulating_supply': 4117312622.380972,
#   'total_supply': 4117312622.380972,
#   'max_supply': None,
#   'ath': 1.081,
#   'ath_change_percentage': -7.49926,
#   'ath_date': '2026-04-02T07:35:31.426Z',
#   'atl': 0.959426,
#   'atl_change_percentage': 4.20719,
#   'atl_date': '2024-12-05T22:31:13.430Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:43.868Z'},
#  {'id': 'sui',
#   'symbol': 'sui',
#   'name': 'Sui',
#   'image': 'https://coin-images.coingecko.com/coins/images/26375/large/sui-ocean-square.png?1727791290',
#   'current_price': 1.013,
#   'market_cap': 4008100384,
#   'market_cap_rank': 30,
#   'fully_diluted_valuation': 10138391271,
#   'total_volume': 630788790,
#   'high_24h': 1.04,
#   'low_24h': 0.975881,
#   'price_change_24h': 0.03186113,
#   'price_change_percentage_24h': 3.24631,
#   'market_cap_change_24h': 128548046,
#   'market_cap_change_percentage_24h': 3.31348,
#   'circulating_supply': 3953388932.071221,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 5.35,
#   'ath_change_percentage': -81.04733,
#   'ath_date': '2025-01-04T22:56:18.063Z',
#   'atl': 0.364846,
#   'atl_change_percentage': 177.73819,
#   'atl_date': '2023-10-19T10:40:30.078Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:43.944Z'},
#  {'id': 'hedera-hashgraph',
#   'symbol': 'hbar',
#   'name': 'Hedera',
#   'image': 'https://coin-images.coingecko.com/coins/images/3688/large/hbar.png?1696504364',
#   'current_price': 0.090622,
#   'market_cap': 3925864632,
#   'market_cap_rank': 31,
#   'fully_diluted_valuation': 4531039014,
#   'total_volume': 121398666,
#   'high_24h': 0.093321,
#   'low_24h': 0.088658,
#   'price_change_24h': 0.00168031,
#   'price_change_percentage_24h': 1.88923,
#   'market_cap_change_24h': 77524815,
#   'market_cap_change_percentage_24h': 2.0145,
#   'circulating_supply': 43321902768.44688,
#   'total_supply': 50000000000.0,
#   'max_supply': 50000000000.0,
#   'ath': 0.569229,
#   'ath_change_percentage': -84.09486,
#   'ath_date': '2021-09-15T10:40:28.318Z',
#   'atl': 0.00986111,
#   'atl_change_percentage': 818.11835,
#   'atl_date': '2020-01-02T17:30:24.852Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:56.014Z'},
#  {'id': 'rain',
#   'symbol': 'rain',
#   'name': 'Rain',
#   'image': 'https://coin-images.coingecko.com/coins/images/69134/large/Rain_logo_1_.png?1762952191',
#   'current_price': 0.00789224,
#   'market_cap': 3777088531,
#   'market_cap_rank': 32,
#   'fully_diluted_valuation': 9079498291,
#   'total_volume': 12202065,
#   'high_24h': 0.0080367,
#   'low_24h': 0.00762119,
#   'price_change_24h': 5.25e-05,
#   'price_change_percentage_24h': 0.66966,
#   'market_cap_change_24h': 30101053,
#   'market_cap_change_percentage_24h': 0.80334,
#   'circulating_supply': 478361384569.355,
#   'total_supply': 1149901925382.59,
#   'max_supply': 1150000000000.0,
#   'ath': 0.01090099,
#   'ath_change_percentage': -27.59497,
#   'ath_date': '2026-02-09T16:50:09.904Z',
#   'atl': 0.00222126,
#   'atl_change_percentage': 255.33285,
#   'atl_date': '2025-09-14T08:56:57.416Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:46.781Z'},
#  {'id': 'shiba-inu',
#   'symbol': 'shib',
#   'name': 'Shiba Inu',
#   'image': 'https://coin-images.coingecko.com/coins/images/11939/large/shiba.png?1696511800',
#   'current_price': 6.37e-06,
#   'market_cap': 3757068886,
#   'market_cap_rank': 33,
#   'fully_diluted_valuation': 3758704849,
#   'total_volume': 185458133,
#   'high_24h': 6.47e-06,
#   'low_24h': 6.1e-06,
#   'price_change_24h': 9.2002e-08,
#   'price_change_percentage_24h': 1.46604,
#   'market_cap_change_24h': 61159237,
#   'market_cap_change_percentage_24h': 1.65478,
#   'circulating_supply': 589243482358331.0,
#   'total_supply': 589500060263766.0,
#   'max_supply': None,
#   'ath': 8.616e-05,
#   'ath_change_percentage': -92.60955,
#   'ath_date': '2021-10-28T03:54:55.568Z',
#   'atl': 5.6366e-11,
#   'atl_change_percentage': 11296571.62115,
#   'atl_date': '2020-11-28T11:26:25.838Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:42.709Z'},
#  {'id': 'the-open-network',
#   'symbol': 'ton',
#   'name': 'Toncoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/17980/large/photo_2024-09-10_17.09.00.jpeg?1725963446',
#   'current_price': 1.4,
#   'market_cap': 3474963367,
#   'market_cap_rank': 34,
#   'fully_diluted_valuation': 7212068436,
#   'total_volume': 150059872,
#   'high_24h': 1.45,
#   'low_24h': 1.39,
#   'price_change_24h': -0.014305322222890382,
#   'price_change_percentage_24h': -1.01224,
#   'market_cap_change_24h': -42808766.050412655,
#   'market_cap_change_percentage_24h': -1.21693,
#   'circulating_supply': 2488292302.457827,
#   'total_supply': 5164294548.982927,
#   'max_supply': None,
#   'ath': 8.25,
#   'ath_change_percentage': -83.11424,
#   'ath_date': '2024-06-15T00:36:51.509Z',
#   'atl': 0.519364,
#   'atl_change_percentage': 168.34455,
#   'atl_date': '2021-09-21T00:33:11.092Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:43.760Z'},
#  {'id': 'crypto-com-chain',
#   'symbol': 'cro',
#   'name': 'Cronos',
#   'image': 'https://coin-images.coingecko.com/coins/images/7310/large/cro_token_logo.png?1696507599',
#   'current_price': 0.07186,
#   'market_cap': 3131224210,
#   'market_cap_rank': 35,
#   'fully_diluted_valuation': 7090209912,
#   'total_volume': 14771447,
#   'high_24h': 0.073554,
#   'low_24h': 0.070216,
#   'price_change_24h': 0.00163511,
#   'price_change_percentage_24h': 2.32838,
#   'market_cap_change_24h': 157599478,
#   'market_cap_change_percentage_24h': 5.29991,
#   'circulating_supply': 43526672578.57255,
#   'total_supply': 98559932044.72707,
#   'max_supply': 100000000000.0,
#   'ath': 0.891544,
#   'ath_change_percentage': -91.93372,
#   'ath_date': '2021-11-24T00:00:00.000Z',
#   'atl': 0.0121196,
#   'atl_change_percentage': 493.37354,
#   'atl_date': '2019-02-08T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:47.353Z'},
#  {'id': 'hashnote-usyc',
#   'symbol': 'usyc',
#   'name': 'Circle USYC',
#   'image': 'https://coin-images.coingecko.com/coins/images/51054/large/Hashnote_SDYC_200x200.png?1730370965',
#   'current_price': 1.12,
#   'market_cap': 2917316871,
#   'market_cap_rank': 36,
#   'fully_diluted_valuation': 2917316871,
#   'total_volume': 112099,
#   'high_24h': None,
#   'low_24h': None,
#   'price_change_24h': None,
#   'price_change_percentage_24h': None,
#   'market_cap_change_24h': None,
#   'market_cap_change_percentage_24h': None,
#   'circulating_supply': 2602451727.473975,
#   'total_supply': 2602451727.473975,
#   'max_supply': None,
#   'ath': 1.12,
#   'ath_change_percentage': -0.09236,
#   'ath_date': '2026-04-08T14:31:05.529Z',
#   'atl': 1.026,
#   'atl_change_percentage': 9.24713,
#   'atl_date': '2024-12-05T22:31:20.475Z',
#   'roi': None,
#   'last_updated': '2026-04-09T23:06:04.591Z'},
#  {'id': 'tether-gold',
#   'symbol': 'xaut',
#   'name': 'Tether Gold',
#   'image': 'https://coin-images.coingecko.com/coins/images/10481/large/logo.png?1774627372',
#   'current_price': 4843.48,
#   'market_cap': 2710628382,
#   'market_cap_rank': 37,
#   'fully_diluted_valuation': 3426404135,
#   'total_volume': 1217625212,
#   'high_24h': 4859.02,
#   'low_24h': 4754.67,
#   'price_change_24h': 72.1,
#   'price_change_percentage_24h': 1.51109,
#   'market_cap_change_24h': 38877529,
#   'market_cap_change_percentage_24h': 1.45513,
#   'circulating_supply': 559898.736688,
#   'total_supply': 707747.089,
#   'max_supply': None,
#   'ath': 5504.62,
#   'ath_change_percentage': -12.02553,
#   'ath_date': '2026-01-29T00:00:00.000Z',
#   'atl': 1447.84,
#   'atl_change_percentage': 234.47429,
#   'atl_date': '2020-03-19T13:45:41.821Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:42.816Z'},
#  {'id': 'world-liberty-financial',
#   'symbol': 'wlfi',
#   'name': 'World Liberty Financial',
#   'image': 'https://coin-images.coingecko.com/coins/images/50767/large/wlfi.png?1756438915',
#   'current_price': 0.082006,
#   'market_cap': 2604460523,
#   'market_cap_rank': 38,
#   'fully_diluted_valuation': 8199008975,
#   'total_volume': 91421958,
#   'high_24h': 0.08389,
#   'low_24h': 0.080084,
#   'price_change_24h': 5.257e-05,
#   'price_change_percentage_24h': 0.06414,
#   'market_cap_change_24h': 579824,
#   'market_cap_change_percentage_24h': 0.02227,
#   'circulating_supply': 31765552773.0,
#   'total_supply': 100000000000.0,
#   'max_supply': 100000000000.0,
#   'ath': 0.331336,
#   'ath_change_percentage': -75.24985,
#   'ath_date': '2025-09-01T12:20:09.597Z',
#   'atl': 0.07726,
#   'atl_change_percentage': 6.1429,
#   'atl_date': '2026-04-11T07:56:04.528Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:45.718Z'},
#  {'id': 'blackrock-usd-institutional-digital-liquidity-fund',
#   'symbol': 'buidl',
#   'name': 'BlackRock USD Institutional Digital Liquidity Fund',
#   'image': 'https://coin-images.coingecko.com/coins/images/36291/large/blackrock.png?1711013223',
#   'current_price': 1.0,
#   'market_cap': 2495781982,
#   'market_cap_rank': 40,
#   'fully_diluted_valuation': 2495781982,
#   'total_volume': 0.0,
#   'high_24h': 1.0,
#   'low_24h': 1.0,
#   'price_change_24h': 0.0,
#   'price_change_percentage_24h': 0.0,
#   'market_cap_change_24h': 240708,
#   'market_cap_change_percentage_24h': 0.00965,
#   'circulating_supply': 2495781982.090449,
#   'total_supply': 2495781982.090449,
#   'max_supply': None,
#   'ath': 1.0,
#   'ath_change_percentage': 0.0,
#   'ath_date': '2025-02-12T05:00:10.912Z',
#   'atl': 1.0,
#   'atl_change_percentage': 0.0,
#   'atl_date': '2025-02-12T05:45:10.196Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:25:09.899Z'},
#  {'id': 'bittensor',
#   'symbol': 'tao',
#   'name': 'Bittensor',
#   'image': 'https://coin-images.coingecko.com/coins/images/28452/large/ARUsPeNQ_400x400.jpeg?1696527447',
#   'current_price': 260.11,
#   'market_cap': 2493639698,
#   'market_cap_rank': 39,
#   'fully_diluted_valuation': 5456262856,
#   'total_volume': 369643169,
#   'high_24h': 266.82,
#   'low_24h': 238.44,
#   'price_change_24h': 21.66,
#   'price_change_percentage_24h': 9.08531,
#   'market_cap_change_24h': 204208144,
#   'market_cap_change_percentage_24h': 8.9196,
#   'circulating_supply': 9597491.0,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 757.6,
#   'ath_change_percentage': -65.70572,
#   'ath_date': '2024-03-07T18:45:36.466Z',
#   'atl': 30.83,
#   'atl_change_percentage': 742.73572,
#   'atl_date': '2023-05-14T08:57:53.732Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:55.985Z'},
#  {'id': 'pax-gold',
#   'symbol': 'paxg',
#   'name': 'PAX Gold',
#   'image': 'https://coin-images.coingecko.com/coins/images/9519/large/paxgold.png?1696509604',
#   'current_price': 4848.61,
#   'market_cap': 2394364027,
#   'market_cap_rank': 41,
#   'fully_diluted_valuation': 2394364027,
#   'total_volume': 297935484,
#   'high_24h': 4863.47,
#   'low_24h': 4758.01,
#   'price_change_24h': 70.22,
#   'price_change_percentage_24h': 1.4695,
#   'market_cap_change_24h': 34530512,
#   'market_cap_change_percentage_24h': 1.46326,
#   'circulating_supply': 493648.962,
#   'total_supply': 493648.962,
#   'max_supply': None,
#   'ath': 5619.09,
#   'ath_change_percentage': -13.74111,
#   'ath_date': '2026-01-29T06:30:56.612Z',
#   'atl': 1399.64,
#   'atl_change_percentage': 246.30046,
#   'atl_date': '2019-11-18T03:09:35.959Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:47.569Z'},
#  {'id': 'global-dollar',
#   'symbol': 'usdg',
#   'name': 'Global Dollar',
#   'image': 'https://coin-images.coingecko.com/coins/images/51281/large/GDN_USDG_Token_200x200.png?1730484111',
#   'current_price': 0.999896,
#   'market_cap': 2279741480,
#   'market_cap_rank': 42,
#   'fully_diluted_valuation': 2279741480,
#   'total_volume': 67228399,
#   'high_24h': 1.0,
#   'low_24h': 0.999721,
#   'price_change_24h': -1.565860814456e-06,
#   'price_change_percentage_24h': -0.00016,
#   'market_cap_change_24h': 28883419,
#   'market_cap_change_percentage_24h': 1.28322,
#   'circulating_supply': 2280029753.326639,
#   'total_supply': 2280029753.326639,
#   'max_supply': None,
#   'ath': 1.65,
#   'ath_change_percentage': -39.57375,
#   'ath_date': '2025-01-30T00:11:05.728Z',
#   'atl': 0.907561,
#   'atl_change_percentage': 10.15918,
#   'atl_date': '2024-11-11T23:55:50.604Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:45.195Z'},
#  {'id': 'mantle',
#   'symbol': 'mnt',
#   'name': 'Mantle',
#   'image': 'https://coin-images.coingecko.com/coins/images/30980/large/MNT_Token_Logo.png?1765516974',
#   'current_price': 0.683237,
#   'market_cap': 2238728878,
#   'market_cap_rank': 43,
#   'fully_diluted_valuation': 4247590525,
#   'total_volume': 48525772,
#   'high_24h': 0.693454,
#   'low_24h': 0.660303,
#   'price_change_24h': 0.01893136,
#   'price_change_percentage_24h': 2.8498,
#   'market_cap_change_24h': 59876060,
#   'market_cap_change_percentage_24h': 2.74805,
#   'circulating_supply': 3277944055.53684,
#   'total_supply': 6219316794.889999,
#   'max_supply': 6219316794.89,
#   'ath': 2.86,
#   'ath_change_percentage': -76.06375,
#   'ath_date': '2025-10-09T01:04:46.659Z',
#   'atl': 0.307978,
#   'atl_change_percentage': 121.89721,
#   'atl_date': '2023-10-18T02:50:46.942Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:43.884Z'},
#  {'id': 'polkadot',
#   'symbol': 'dot',
#   'name': 'Polkadot',
#   'image': 'https://coin-images.coingecko.com/coins/images/12171/large/polkadot.jpg?1766533446',
#   'current_price': 1.33,
#   'market_cap': 2237361525,
#   'market_cap_rank': 44,
#   'fully_diluted_valuation': 2237361525,
#   'total_volume': 283061415,
#   'high_24h': 1.35,
#   'low_24h': 1.29,
#   'price_change_24h': 0.01283934,
#   'price_change_percentage_24h': 0.97401,
#   'market_cap_change_24h': 26870711,
#   'market_cap_change_percentage_24h': 1.2156,
#   'circulating_supply': 1679701948.264083,
#   'total_supply': 1679701948.261698,
#   'max_supply': 2100000000.0,
#   'ath': 54.98,
#   'ath_change_percentage': -97.57763,
#   'ath_date': '2021-11-04T14:10:09.301Z',
#   'atl': 1.15,
#   'atl_change_percentage': 15.94261,
#   'atl_date': '2026-04-15T08:00:42.788Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:43.018Z'},
#  {'id': 'uniswap',
#   'symbol': 'uni',
#   'name': 'Uniswap',
#   'image': 'https://coin-images.coingecko.com/coins/images/12504/large/uniswap-logo.png?1720676669',
#   'current_price': 3.5,
#   'market_cap': 2217600019,
#   'market_cap_rank': 45,
#   'fully_diluted_valuation': 3138998722,
#   'total_volume': 234675063,
#   'high_24h': 3.57,
#   'low_24h': 3.33,
#   'price_change_24h': 0.105571,
#   'price_change_percentage_24h': 3.11362,
#   'market_cap_change_24h': 74223009,
#   'market_cap_change_percentage_24h': 3.4629,
#   'circulating_supply': 633561603.6037512,
#   'total_supply': 896802420.0366304,
#   'max_supply': 1000000000.0,
#   'ath': 44.92,
#   'ath_change_percentage': -92.21577,
#   'ath_date': '2021-05-03T05:25:04.822Z',
#   'atl': 1.03,
#   'atl_change_percentage': 239.41235,
#   'atl_date': '2020-09-17T01:20:38.214Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:43.223Z'},
#  {'id': 'near',
#   'symbol': 'near',
#   'name': 'NEAR Protocol',
#   'image': 'https://coin-images.coingecko.com/coins/images/10365/large/near.jpg?1696510367',
#   'current_price': 1.42,
#   'market_cap': 1840107351,
#   'market_cap_rank': 47,
#   'fully_diluted_valuation': 1840107379,
#   'total_volume': 269484180,
#   'high_24h': 1.44,
#   'low_24h': 1.38,
#   'price_change_24h': 0.02251943,
#   'price_change_percentage_24h': 1.60652,
#   'market_cap_change_24h': 29619684,
#   'market_cap_change_percentage_24h': 1.63601,
#   'circulating_supply': 1293130485.0,
#   'total_supply': 1293130505.0,
#   'max_supply': None,
#   'ath': 20.44,
#   'ath_change_percentage': -93.05966,
#   'ath_date': '2022-01-16T22:09:45.873Z',
#   'atl': 0.526762,
#   'atl_change_percentage': 169.2817,
#   'atl_date': '2020-11-04T16:09:15.137Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:42.444Z'},
#  {'id': 'pi-network',
#   'symbol': 'pi',
#   'name': 'Pi Network',
#   'image': 'https://coin-images.coingecko.com/coins/images/54342/large/pi_network.jpg?1739347576',
#   'current_price': 0.180663,
#   'market_cap': 1836604368,
#   'market_cap_rank': 46,
#   'fully_diluted_valuation': 2825129513,
#   'total_volume': 32974232,
#   'high_24h': 0.182398,
#   'low_24h': 0.170999,
#   'price_change_24h': 0.0083025,
#   'price_change_percentage_24h': 4.81693,
#   'market_cap_change_24h': 87846605,
#   'market_cap_change_percentage_24h': 5.02337,
#   'circulating_supply': 10165438561.16126,
#   'total_supply': 15636835564.79076,
#   'max_supply': 100000000000.0,
#   'ath': 2.99,
#   'ath_change_percentage': -93.94786,
#   'ath_date': '2025-02-26T16:41:03.732Z',
#   'atl': 0.131244,
#   'atl_change_percentage': 37.76991,
#   'atl_date': '2026-02-11T17:06:46.605Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:45.926Z'},
#  {'id': 'sky',
#   'symbol': 'sky',
#   'name': 'Sky',
#   'image': 'https://coin-images.coingecko.com/coins/images/39925/large/sky.jpg?1724827980',
#   'current_price': 0.078509,
#   'market_cap': 1819807765,
#   'market_cap_rank': 48,
#   'fully_diluted_valuation': 1841362378,
#   'total_volume': 13015786,
#   'high_24h': 0.079398,
#   'low_24h': 0.075838,
#   'price_change_24h': 0.0026709,
#   'price_change_percentage_24h': 3.52185,
#   'market_cap_change_24h': 61891931,
#   'market_cap_change_percentage_24h': 3.52076,
#   'circulating_supply': 23188015970.73355,
#   'total_supply': 23462665147.36596,
#   'max_supply': 23462665147.3,
#   'ath': 0.100535,
#   'ath_change_percentage': -22.09901,
#   'ath_date': '2024-12-04T10:13:57.264Z',
#   'atl': 0.03582727,
#   'atl_change_percentage': 118.59869,
#   'atl_date': '2025-02-03T05:01:48.626Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:44.995Z'},
#  {'id': 'okb',
#   'symbol': 'okb',
#   'name': 'OKB',
#   'image': 'https://coin-images.coingecko.com/coins/images/4463/large/WeChat_Image_20220118095654.png?1696505053',
#   'current_price': 86.56,
#   'market_cap': 1817063727,
#   'market_cap_rank': 49,
#   'fully_diluted_valuation': 1817063727,
#   'total_volume': 23331614,
#   'high_24h': 87.62,
#   'low_24h': 85.4,
#   'price_change_24h': 0.991961,
#   'price_change_percentage_24h': 1.15924,
#   'market_cap_change_24h': 21983566,
#   'market_cap_change_percentage_24h': 1.22466,
#   'circulating_supply': 21000000.0,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 228.74,
#   'ath_change_percentage': -62.1811,
#   'ath_date': '2025-10-05T00:00:00.000Z',
#   'atl': 0.580608,
#   'atl_change_percentage': 14799.33409,
#   'atl_date': '2019-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:45.044Z'},
#  {'id': 'falcon-finance',
#   'symbol': 'usdf',
#   'name': 'Falcon USD',
#   'image': 'https://coin-images.coingecko.com/coins/images/54558/large/ff_200_X_200.png?1740741076',
#   'current_price': 0.998181,
#   'market_cap': 1786047458,
#   'market_cap_rank': 50,
#   'fully_diluted_valuation': 1786047458,
#   'total_volume': 1057866,
#   'high_24h': 0.998879,
#   'low_24h': 0.997606,
#   'price_change_24h': 4.793e-05,
#   'price_change_percentage_24h': 0.0048,
#   'market_cap_change_24h': -734815.322619915,
#   'market_cap_change_percentage_24h': -0.04113,
#   'circulating_supply': 1789407824.783388,
#   'total_supply': 1789407824.783388,
#   'max_supply': None,
#   'ath': 1.075,
#   'ath_change_percentage': -7.12418,
#   'ath_date': '2025-05-08T21:25:42.071Z',
#   'atl': 0.943422,
#   'atl_change_percentage': 5.78795,
#   'atl_date': '2025-07-08T10:16:34.749Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:45.702Z'},
#  {'id': 'aave',
#   'symbol': 'aave',
#   'name': 'Aave',
#   'image': 'https://coin-images.coingecko.com/coins/images/12645/large/aave-token-round.png?1720472354',
#   'current_price': 117.17,
#   'market_cap': 1775882046,
#   'market_cap_rank': 51,
#   'fully_diluted_valuation': 1873549225,
#   'total_volume': 485491928,
#   'high_24h': 118.65,
#   'low_24h': 111.81,
#   'price_change_24h': 4.75,
#   'price_change_percentage_24h': 4.22643,
#   'market_cap_change_24h': 68555407,
#   'market_cap_change_percentage_24h': 4.01537,
#   'circulating_supply': 15165928.044536555,
#   'total_supply': 16000000.0,
#   'max_supply': 16000000.0,
#   'ath': 661.69,
#   'ath_change_percentage': -82.30958,
#   'ath_date': '2021-05-18T21:19:59.514Z',
#   'atl': 26.02,
#   'atl_change_percentage': 349.81386,
#   'atl_date': '2020-11-05T09:20:11.928Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:42.936Z'},
#  {'id': 'pepe',
#   'symbol': 'pepe',
#   'name': 'Pepe',
#   'image': 'https://coin-images.coingecko.com/coins/images/29850/large/pepe-token.jpeg?1696528776',
#   'current_price': 4.06e-06,
#   'market_cap': 1708059470,
#   'market_cap_rank': 52,
#   'fully_diluted_valuation': 1708059470,
#   'total_volume': 705490545,
#   'high_24h': 4.1e-06,
#   'low_24h': 3.83e-06,
#   'price_change_24h': 1.345e-07,
#   'price_change_percentage_24h': 3.42294,
#   'market_cap_change_24h': 45185931,
#   'market_cap_change_percentage_24h': 2.71734,
#   'circulating_supply': 420690000000000.0,
#   'total_supply': 420690000000000.0,
#   'max_supply': 420690000000000.0,
#   'ath': 2.803e-05,
#   'ath_change_percentage': -85.50072,
#   'ath_date': '2024-12-09T16:30:35.828Z',
#   'atl': 5.5142e-08,
#   'atl_change_percentage': 7269.80312,
#   'atl_date': '2023-04-18T02:14:41.591Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:51.080Z'},
#  {'id': 'aster-2',
#   'symbol': 'aster',
#   'name': 'Aster',
#   'image': 'https://coin-images.coingecko.com/coins/images/69040/large/_ASTER.png?1757326782',
#   'current_price': 0.687563,
#   'market_cap': 1689357350,
#   'market_cap_rank': 53,
#   'fully_diluted_valuation': 5375117378,
#   'total_volume': 162759814,
#   'high_24h': 0.698685,
#   'low_24h': 0.676153,
#   'price_change_24h': 0.00800029,
#   'price_change_percentage_24h': 1.17727,
#   'market_cap_change_24h': 23202855,
#   'market_cap_change_percentage_24h': 1.3926,
#   'circulating_supply': 2458559719.12999,
#   'total_supply': 7822529124.595041,
#   'max_supply': 8000000000.0,
#   'ath': 2.41,
#   'ath_change_percentage': -71.45546,
#   'ath_date': '2025-09-24T11:18:14.634Z',
#   'atl': 0.099713,
#   'atl_change_percentage': 589.5383,
#   'atl_date': '2025-09-17T12:05:36.771Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:46.761Z'},
#  {'id': 'htx-dao',
#   'symbol': 'htx',
#   'name': 'HTX DAO',
#   'image': 'https://coin-images.coingecko.com/coins/images/35491/large/Frame_1321318576.png?1708908626',
#   'current_price': 1.78e-06,
#   'market_cap': 1610192399,
#   'market_cap_rank': 54,
#   'fully_diluted_valuation': 1610192399,
#   'total_volume': 13463638,
#   'high_24h': 1.79e-06,
#   'low_24h': 1.78e-06,
#   'price_change_24h': -3.307772742e-09,
#   'price_change_percentage_24h': -0.18572,
#   'market_cap_change_24h': -2939197.215789795,
#   'market_cap_change_percentage_24h': -0.1822,
#   'circulating_supply': 905707664073577.8,
#   'total_supply': 905707664073577.8,
#   'max_supply': 999990000000000.0,
#   'ath': 3.75e-06,
#   'ath_change_percentage': -52.60491,
#   'ath_date': '2024-12-04T00:16:20.770Z',
#   'atl': 8.00816e-07,
#   'atl_change_percentage': 122.02665,
#   'atl_date': '2024-08-05T13:31:33.427Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:33:47.981Z'},
#  {'id': 'usdd',
#   'symbol': 'usdd',
#   'name': 'USDD',
#   'image': 'https://coin-images.coingecko.com/coins/images/25380/large/UUSD.jpg?1696524513',
#   'current_price': 1.0,
#   'market_cap': 1541556785,
#   'market_cap_rank': 55,
#   'fully_diluted_valuation': 1541556785,
#   'total_volume': 69650358,
#   'high_24h': 1.0,
#   'low_24h': 1.0,
#   'price_change_24h': 4.065e-05,
#   'price_change_percentage_24h': 0.00406,
# ...
#  {'id': 'grx-chain',
#   'symbol': 'grx',
#   'name': 'GRX Chain',
#   'image': 'https://coin-images.coingecko.com/coins/images/71011/large/Untitled_design_%283%29.png?1765178472',
#   'current_price': 11.15,
#   'market_cap': 105953412,
#   'market_cap_rank': 284,
#   'fully_diluted_valuation': 111362738,
#   'total_volume': 30059568,
#   'high_24h': 11.38,
#   'low_24h': 10.73,
#   'price_change_24h': -0.1902749215081414,
#   'price_change_percentage_24h': -1.67747,
#   'market_cap_change_24h': -1945643.273217097,
#   'market_cap_change_percentage_24h': -1.80321,
#   'circulating_supply': 9512395.0,
#   'total_supply': 9998039.0,
#   'max_supply': 10000000.0,
#   'ath': 13.26,
#   'ath_change_percentage': -15.99969,
#   'ath_date': '2026-02-26T22:25:48.793Z',
#   'atl': 0.868057,
#   'atl_change_percentage': 1183.17211,
#   'atl_date': '2026-02-14T17:00:45.524Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:34:33.113Z'},
#  {'id': 'melania-meme',
#   'symbol': 'melania',
#   'name': 'Melania Meme',
#   'image': 'https://coin-images.coingecko.com/coins/images/53775/large/melania-meme.png?1737329885',
#   'current_price': 0.111611,
#   'market_cap': 105621648,
#   'market_cap_rank': 285,
#   'fully_diluted_valuation': 110888873,
#   'total_volume': 26492850,
#   'high_24h': 0.116073,
#   'low_24h': 0.108835,
#   'price_change_24h': 0.00194249,
#   'price_change_percentage_24h': 1.77124,
#   'market_cap_change_24h': 1953489,
#   'market_cap_change_percentage_24h': 1.88437,
#   'circulating_supply': 952496375.911841,
#   'total_supply': 999996233.372997,
#   'max_supply': 1000000000.0,
#   'ath': 13.05,
#   'ath_change_percentage': -99.15034,
#   'ath_date': '2025-01-20T07:00:55.462Z',
#   'atl': 0.089932,
#   'atl_change_percentage': 23.31379,
#   'atl_date': '2025-10-22T22:43:19.403Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:34:29.716Z'},
#  {'id': 'chutes',
#   'symbol': 'sn64',
#   'name': 'Chutes',
#   'image': 'https://coin-images.coingecko.com/coins/images/66308/large/chutes.jpg?1749181700',
#   'current_price': 21.96,
#   'market_cap': 105579664,
#   'market_cap_rank': 280,
#   'fully_diluted_valuation': 105579664,
#   'total_volume': 5122869,
#   'high_24h': 22.65,
#   'low_24h': 19.8,
#   'price_change_24h': 2.16,
#   'price_change_percentage_24h': 10.91836,
#   'market_cap_change_24h': 10312970,
#   'market_cap_change_percentage_24h': 10.82537,
#   'circulating_supply': 4818255.894807588,
#   'total_supply': 4818255.894807588,
#   'max_supply': 21000000.0,
#   'ath': 104.42,
#   'ath_change_percentage': -78.94032,
#   'ath_date': '2025-06-10T11:46:43.336Z',
#   'atl': 13.04,
#   'atl_change_percentage': 68.64665,
#   'atl_date': '2026-02-06T00:25:26.113Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:34:30.114Z'},
#  {'id': 'build-on',
#   'symbol': 'b',
#   'name': 'BUILDon',
#   'image': 'https://coin-images.coingecko.com/coins/images/55974/large/T7asvmCb_400x400.jpg?1747902862',
#   'current_price': 0.105137,
#   'market_cap': 105458795,
#   'market_cap_rank': 286,
#   'fully_diluted_valuation': 105458795,
#   'total_volume': 7719476,
#   'high_24h': 0.107569,
#   'low_24h': 0.100323,
#   'price_change_24h': 0.00391948,
#   'price_change_percentage_24h': 3.87234,
#   'market_cap_change_24h': 4241630,
#   'market_cap_change_percentage_24h': 4.19062,
#   'circulating_supply': 1000000000.0,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 0.731588,
#   'ath_change_percentage': -85.68155,
#   'ath_date': '2025-08-31T21:31:16.268Z',
#   'atl': 0.082973,
#   'atl_change_percentage': 26.24844,
#   'atl_date': '2025-10-10T21:31:21.514Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:34:30.071Z'},
#  {'id': 'securitize-tokenized-aaa-clo-fund',
#   'symbol': 'stac',
#   'name': 'Securitize Tokenized AAA CLO Fund',
#   'image': 'https://coin-images.coingecko.com/coins/images/71167/large/stac_logo.png?1766163743',
#   'current_price': 1012.35,
#   'market_cap': 104888823,
#   'market_cap_rank': 287,
#   'fully_diluted_valuation': 104888823,
#   'total_volume': 0.0,
#   'high_24h': 1012.77,
#   'low_24h': 1011.07,
#   'price_change_24h': 0.11137,
#   'price_change_percentage_24h': 0.011,
#   'market_cap_change_24h': 13152.19,
#   'market_cap_change_percentage_24h': 0.01254,
#   'circulating_supply': 103609.694673,
#   'total_supply': 103609.694673,
#   'max_supply': None,
#   'ath': 1012.99,
#   'ath_change_percentage': -0.06002,
#   'ath_date': '2026-02-05T22:30:05.739Z',
#   'atl': 997.66,
#   'atl_change_percentage': 1.4754,
#   'atl_date': '2026-02-06T00:15:06.823Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:30:06.258Z'},
#  {'id': 'apecoin',
#   'symbol': 'ape',
#   'name': 'ApeCoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/24383/large/APECOIN.png?1756551529',
#   'current_price': 0.104826,
#   'market_cap': 104724249,
#   'market_cap_rank': 289,
#   'fully_diluted_valuation': 104724249,
#   'total_volume': 22771317,
#   'high_24h': 0.10688,
#   'low_24h': 0.099526,
#   'price_change_24h': 0.001534,
#   'price_change_percentage_24h': 1.48512,
#   'market_cap_change_24h': 1780295,
#   'market_cap_change_percentage_24h': 1.72938,
#   'circulating_supply': 1000000000.0,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 26.7,
#   'ath_change_percentage': -99.60813,
#   'ath_date': '2022-04-28T21:44:21.164Z',
#   'atl': 0.08172,
#   'atl_change_percentage': 28.01911,
#   'atl_date': '2026-04-02T21:56:48.220Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:34:27.463Z'},
#  {'id': 'seeker',
#   'symbol': 'skr',
#   'name': 'Seeker',
#   'image': 'https://coin-images.coingecko.com/coins/images/70974/large/seeker-logo.jpg?1764922774',
#   'current_price': 0.01709997,
#   'market_cap': 104689357,
#   'market_cap_rank': 288,
#   'fully_diluted_valuation': 174731359,
#   'total_volume': 4957832,
#   'high_24h': 0.0174994,
#   'low_24h': 0.01690539,
#   'price_change_24h': 0.00012661,
#   'price_change_percentage_24h': 0.74594,
#   'market_cap_change_24h': 832376,
#   'market_cap_change_percentage_24h': 0.80146,
#   'circulating_supply': 6128128220.562428,
#   'total_supply': 10228128220.55725,
#   'max_supply': None,
#   'ath': 0.055818,
#   'ath_change_percentage': -69.42421,
#   'ath_date': '2026-01-22T03:32:20.056Z',
#   'atl': 0.00542271,
#   'atl_change_percentage': 214.72956,
#   'atl_date': '2026-01-21T02:11:35.450Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:34:31.295Z'},
#  {'id': 'beam-2',
#   'symbol': 'beam',
#   'name': 'Beam',
#   'image': 'https://coin-images.coingecko.com/coins/images/32417/large/cgicon.png?1747892021',
#   'current_price': 0.00203319,
#   'market_cap': 104204810,
#   'market_cap_rank': 290,
#   'fully_diluted_valuation': 118769056,
#   'total_volume': 7697619,
#   'high_24h': 0.0020679,
#   'low_24h': 0.00200166,
#   'price_change_24h': 2.997e-05,
#   'price_change_percentage_24h': 1.49614,
#   'market_cap_change_24h': 1396896,
#   'market_cap_change_percentage_24h': 1.35874,
#   'circulating_supply': 51300184687.0,
#   'total_supply': 58470184687.0,
#   'max_supply': 58470184687.0,
#   'ath': 0.04416304,
#   'ath_change_percentage': -95.40837,
#   'ath_date': '2024-03-10T10:40:22.381Z',
#   'atl': 0.00157473,
#   'atl_change_percentage': 28.77123,
#   'atl_date': '2026-03-29T22:55:17.804Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:34:28.136Z'},
#  {'id': 'usdu',
#   'symbol': 'usdu',
#   'name': 'USDu',
#   'image': 'https://coin-images.coingecko.com/coins/images/67726/large/USDu_Icon_512x512.png?1770780851',
#   'current_price': 1.0,
#   'market_cap': 103640087,
#   'market_cap_rank': 291,
#   'fully_diluted_valuation': 103640186,
#   'total_volume': 51740,
#   'high_24h': 1.0,
#   'low_24h': 0.992583,
#   'price_change_24h': 0.00747757,
#   'price_change_percentage_24h': 0.75334,
#   'market_cap_change_24h': 1265771,
#   'market_cap_change_percentage_24h': 1.23641,
#   'circulating_supply': 103632436.9677667,
#   'total_supply': 103632535.9728908,
#   'max_supply': None,
#   'ath': 1.018,
#   'ath_change_percentage': -1.80884,
#   'ath_date': '2025-12-06T20:30:09.576Z',
#   'atl': 0.957425,
#   'atl_change_percentage': 4.45061,
#   'atl_date': '2026-02-06T06:40:56.133Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:34:30.448Z'},
#  {'id': 'mnee-usd-stablecoin',
#   'symbol': 'mnee',
#   'name': 'MNEE USD Stablecoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/39459/large/MNEE_logo_no_BG.png?1725666891',
#   'current_price': 1.001,
#   'market_cap': 102389034,
#   'market_cap_rank': 292,
#   'fully_diluted_valuation': 102389034,
#   'total_volume': 143880,
#   'high_24h': 1.001,
#   'low_24h': 0.999196,
#   'price_change_24h': 0.00050468,
#   'price_change_percentage_24h': 0.05045,
#   'market_cap_change_24h': 1008252,
#   'market_cap_change_percentage_24h': 0.99452,
#   'circulating_supply': 102368564.9023,
#   'total_supply': 101539681.0823,
#   'max_supply': None,
#   'ath': 1.045,
#   'ath_change_percentage': -4.26102,
#   'ath_date': '2024-08-08T23:11:28.286Z',
#   'atl': 0.584655,
#   'atl_change_percentage': 71.19498,
#   'atl_date': '2024-08-08T06:50:34.888Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:34:28.970Z'},
#  {'id': 'banana-for-scale-2',
#   'symbol': 'bananas31',
#   'name': 'Banana For Scale',
#   'image': 'https://coin-images.coingecko.com/coins/images/52230/large/Banana_token_image.png?1732801941',
#   'current_price': 0.01016534,
#   'market_cap': 101673466,
#   'market_cap_rank': 293,
#   'fully_diluted_valuation': 101673466,
#   'total_volume': 22790679,
#   'high_24h': 0.01106176,
#   'low_24h': 0.01012398,
#   'price_change_24h': -0.000293481314171527,
#   'price_change_percentage_24h': -2.80607,
#   'market_cap_change_24h': -3161862.9705173075,
#   'market_cap_change_percentage_24h': -3.01603,
#   'circulating_supply': 10000000000.0,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 0.057741,
#   'ath_change_percentage': -82.38303,
#   'ath_date': '2025-07-11T01:35:56.619Z',
#   'atl': 0.00072336,
#   'atl_change_percentage': 1306.23804,
#   'atl_date': '2025-02-03T05:11:44.101Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:34:29.553Z'},
#  {'id': 'lombard-protocol',
#   'symbol': 'bard',
#   'name': 'Lombard',
#   'image': 'https://coin-images.coingecko.com/coins/images/68404/large/bard.png?1755657543',
#   'current_price': 0.335593,
#   'market_cap': 101302809,
#   'market_cap_rank': 294,
#   'fully_diluted_valuation': 335578664,
#   'total_volume': 24772603,
#   'high_24h': 0.340698,
#   'low_24h': 0.322805,
#   'price_change_24h': 0.01278828,
#   'price_change_percentage_24h': 3.96161,
#   'market_cap_change_24h': 3895798,
#   'market_cap_change_percentage_24h': 3.99951,
#   'circulating_supply': 301875000.0,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 1.7,
#   'ath_change_percentage': -80.29537,
#   'ath_date': '2026-03-05T20:26:18.448Z',
#   'atl': 0.294275,
#   'atl_change_percentage': 13.87408,
#   'atl_date': '2026-04-03T00:50:24.802Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:34:30.748Z'},
#  {'id': 'palm-usd',
#   'symbol': 'pusd',
#   'name': 'Palm USD',
#   'image': 'https://coin-images.coingecko.com/coins/images/102172705/large/Pusd.png?1774981810',
#   'current_price': 0.999782,
#   'market_cap': 101265405,
#   'market_cap_rank': 295,
#   'fully_diluted_valuation': 2825463126,
#   'total_volume': 119607,
#   'high_24h': 1.0,
#   'low_24h': 0.999338,
#   'price_change_24h': -0.000175698609399588,
#   'price_change_percentage_24h': -0.01757,
#   'market_cap_change_24h': -16293.512102216482,
#   'market_cap_change_percentage_24h': -0.01609,
#   'circulating_supply': 101285937.115771,
#   'total_supply': 2826036007.115771,
#   'max_supply': None,
#   'ath': 1.001,
#   'ath_change_percentage': -0.07268,
#   'ath_date': '2026-04-14T14:55:03.176Z',
#   'atl': 0.998331,
#   'atl_change_percentage': 0.14505,
#   'atl_date': '2026-03-31T21:27:27.168Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:34:26.186Z'},
#  {'id': 'qtum',
#   'symbol': 'qtum',
#   'name': 'Qtum',
#   'image': 'https://coin-images.coingecko.com/coins/images/684/large/Qtum_Logo_blue_CG.png?1696501874',
#   'current_price': 0.954494,
#   'market_cap': 101157726,
#   'market_cap_rank': 296,
#   'fully_diluted_valuation': 102890959,
#   'total_volume': 7279245,
#   'high_24h': 0.96811,
#   'low_24h': 0.925216,
#   'price_change_24h': 0.02707399,
#   'price_change_percentage_24h': 2.91928,
#   'market_cap_change_24h': 2785148,
#   'market_cap_change_percentage_24h': 2.83122,
#   'circulating_supply': 106006101.25,
#   'total_supply': 107822406.0,
#   'max_supply': None,
#   'ath': 100.22,
#   'ath_change_percentage': -99.04825,
#   'ath_date': '2018-01-06T00:00:00.000Z',
#   'atl': 0.783142,
#   'atl_change_percentage': 21.80198,
#   'atl_date': '2020-03-13T02:22:57.149Z',
#   'roi': {'times': 2.1816465115578048,
#    'currency': 'usd',
#    'percentage': 218.16465115578046},
#   'last_updated': '2026-04-17T18:34:30.710Z'},
#  {'id': 'rollbit-coin',
#   'symbol': 'rlb',
#   'name': 'Rollbit Coin',
#   'image': 'https://coin-images.coingecko.com/coins/images/24552/large/unziL6wO_400x400.jpg?1696523729',
#   'current_price': 0.059297,
#   'market_cap': 100951349,
#   'market_cap_rank': 297,
#   'fully_diluted_valuation': 100954603,
#   'total_volume': 211019,
#   'high_24h': 0.059546,
#   'low_24h': 0.057799,
#   'price_change_24h': 0.00149778,
#   'price_change_percentage_24h': 2.59136,
#   'market_cap_change_24h': 2465329,
#   'market_cap_change_percentage_24h': 2.50323,
#   'circulating_supply': 1702381518.434846,
#   'total_supply': 1702436380.319295,
#   'max_supply': 5000000000.0,
#   'ath': 0.264358,
#   'ath_change_percentage': -77.56474,
#   'ath_date': '2023-11-11T17:10:05.473Z',
#   'atl': 0.00093506,
#   'atl_change_percentage': 6242.84509,
#   'atl_date': '2022-07-02T02:46:34.730Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:34:27.434Z'},
#  {'id': 'infinifi-usd',
#   'symbol': 'iusd',
#   'name': 'InfiniFi USD',
#   'image': 'https://coin-images.coingecko.com/coins/images/67385/large/iusd.jpg?1752628477',
#   'current_price': 0.999195,
#   'market_cap': 100741185,
#   'market_cap_rank': 298,
#   'fully_diluted_valuation': 100741185,
#   'total_volume': 52956,
#   'high_24h': 1.001,
#   'low_24h': 0.998818,
#   'price_change_24h': -0.000900394368718027,
#   'price_change_percentage_24h': -0.09003,
#   'market_cap_change_24h': -5089813.3034875095,
#   'market_cap_change_percentage_24h': -4.80938,
#   'circulating_supply': 100821715.9815977,
#   'total_supply': 100821715.9815977,
#   'max_supply': None,
#   'ath': 1.38,
#   'ath_change_percentage': -27.50754,
#   'ath_date': '2026-01-11T04:35:54.115Z',
#   'atl': 0.243118,
#   'atl_change_percentage': 310.96038,
#   'atl_date': '2026-01-04T19:15:08.862Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:34:30.426Z'},
#  {'id': 'ring-usd',
#   'symbol': 'usdr',
#   'name': 'Ring USD',
#   'image': 'https://coin-images.coingecko.com/coins/images/69350/large/logo_USDR_color_512x512.png?1758260860',
#   'current_price': 0.999717,
#   'market_cap': 100378792,
#   'market_cap_rank': 299,
#   'fully_diluted_valuation': 100378792,
#   'total_volume': 14731.94,
#   'high_24h': 1.001,
#   'low_24h': 0.99924,
#   'price_change_24h': 0.00017682,
#   'price_change_percentage_24h': 0.01769,
#   'market_cap_change_24h': 29043,
#   'market_cap_change_percentage_24h': 0.02894,
#   'circulating_supply': 100400000.0,
#   'total_supply': 100400000.0,
#   'max_supply': None,
#   'ath': 1.08,
#   'ath_change_percentage': -7.46316,
#   'ath_date': '2025-12-09T17:11:49.830Z',
#   'atl': 0.941515,
#   'atl_change_percentage': 6.19195,
#   'atl_date': '2026-02-01T23:12:26.620Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:34:30.807Z'},
#  {'id': 'tradable-singapore-fintech-ssl',
#   'symbol': 'pc0000077',
#   'name': 'Tradable Singapore Fintech SSL',
#   'image': 'https://coin-images.coingecko.com/coins/images/66878/large/tradable.jpg?1750921608',
#   'current_price': 1.0,
#   'market_cap': 100000000,
#   'market_cap_rank': 300,
#   'fully_diluted_valuation': 100000000,
#   'total_volume': 0.0,
#   'high_24h': 1.0,
#   'low_24h': 1.0,
#   'price_change_24h': 0.0,
#   'price_change_percentage_24h': 0.0,
#   'market_cap_change_24h': 0.0,
#   'market_cap_change_percentage_24h': 0.0,
#   'circulating_supply': 100000000.0,
#   'total_supply': 100000000.0,
#   'max_supply': 100000000.0,
#   'ath': 1.0,
#   'ath_change_percentage': 0.0,
#   'ath_date': '2025-07-03T10:25:10.344Z',
#   'atl': 1.0,
#   'atl_change_percentage': 0.0,
#   'atl_date': '2025-07-03T10:25:10.344Z',
#   'roi': None,
#   'last_updated': '2026-04-17T18:30:11.475Z'}]

# %%
import pandas as pd

df = pd.DataFrame(all_data)

# %%
df.columns
# Out:
# Index(['id', 'symbol', 'name', 'image', 'current_price', 'market_cap',
#        'market_cap_rank', 'fully_diluted_valuation', 'total_volume',
#        'high_24h', 'low_24h', 'price_change_24h',
#        'price_change_percentage_24h', 'market_cap_change_24h',
#        'market_cap_change_percentage_24h', 'circulating_supply',
#        'total_supply', 'max_supply', 'ath', 'ath_change_percentage',
#        'ath_date', 'atl', 'atl_change_percentage', 'atl_date', 'roi',
#        'last_updated'],
#       dtype='str')

# %%
df.head()
# Out:
#             id symbol      name  \
# 0      bitcoin    btc   Bitcoin
# 1     ethereum    eth  Ethereum
# 2       tether   usdt    Tether
# 3       ripple    xrp       XRP
# 4  binancecoin    bnb       BNB
#
#                                                image  current_price  \
# 0  https://coin-images.coingecko.com/coins/images...       77224.00
# 1  https://coin-images.coingecko.com/coins/images...        2423.59
# 2  https://coin-images.coingecko.com/coins/images...           1.00
# 3  https://coin-images.coingecko.com/coins/images...           1.48
# 4  https://coin-images.coingecko.com/coins/images...         639.94
#
#       market_cap  market_cap_rank  fully_diluted_valuation  total_volume  \
# 0  1545460597452                1            1545461832760  5.974516e+10
# 1   292370944641                2             292370944641  2.519844e+10
# 2   185873878309                3             191342727115  9.925832e+10
# 3    91086540096                4             147919390223  4.476654e+09
# 4    86224049098                5              86224048554  1.515209e+09
#
#    high_24h  ...  total_supply    max_supply        ath  \
# 0  78240.00  ...  2.001719e+07  2.100000e+07  126080.00
# 1   2462.81  ...  1.206909e+08           NaN    4946.05
# 2      1.00  ...  1.912759e+11           NaN       1.32
# 3      1.51  ...  9.998568e+10  1.000000e+11       3.65
# 4    645.76  ...  1.347868e+08  2.000000e+08    1369.99
#
#    ath_change_percentage                  ath_date        atl  \
# 0              -38.75027  2025-10-06T18:57:42.558Z  67.810000
# 1              -50.99942  2025-08-24T19:21:03.333Z   0.432979
# 2              -24.39553  2018-07-24T00:00:00.000Z   0.572521
# 3              -59.46670  2025-07-18T03:40:53.808Z   0.002686
# 4              -53.28875  2025-10-13T08:41:24.131Z   0.039818
#
#    atl_change_percentage                  atl_date  \
# 0           1.137840e+05  2013-07-06T00:00:00.000Z
# 1           5.596484e+05  2015-10-20T00:00:00.000Z
# 2           7.472184e+01  2015-03-02T00:00:00.000Z
# 3           5.492173e+04  2014-05-22T00:00:00.000Z
# 4           1.607075e+06  2017-10-19T00:00:00.000Z
#
#                                                  roi              last_updated
# 0                                               None  2026-04-17T18:33:57.798Z
# 1  {'times': 40.97647849225858, 'currency': 'btc'...  2026-04-17T18:33:57.888Z
# 2                                               None  2026-04-17T18:33:57.842Z
# 3                                               None  2026-04-17T18:33:57.495Z
# 4                                               None  2026-04-17T18:33:58.044Z
#
# [5 rows x 26 columns]

# %%
df = df[[
    "id",
    "symbol",
    "name",
    "current_price",
    "market_cap",
    "market_cap_rank",
    "total_volume",
    "price_change_percentage_24h",
    "high_24h",
    "low_24h",
    "circulating_supply",
    "ath",
    "atl",
    "last_updated"
]]

# %%
df.head()
# Out:
#             id symbol      name  current_price     market_cap  \
# 0      bitcoin    btc   Bitcoin       77224.00  1545460597452
# 1     ethereum    eth  Ethereum        2423.59   292370944641
# 2       tether   usdt    Tether           1.00   185873878309
# 3       ripple    xrp       XRP           1.48    91086540096
# 4  binancecoin    bnb       BNB         639.94    86224049098
#
#    market_cap_rank  total_volume  price_change_percentage_24h  high_24h  \
# 0                1  5.974516e+10                      3.76870  78240.00
# 1                2  2.519844e+10                      4.10618   2462.81
# 2                3  9.925832e+10                      0.01563      1.00
# 3                4  4.476654e+09                      3.04220      1.51
# 4                5  1.515209e+09                      1.49161    645.76
#
#     low_24h  circulating_supply        ath        atl  \
# 0  74419.00        2.001717e+07  126080.00  67.810000
# 1   2319.42        1.206909e+08    4946.05   0.432979
# 2      1.00        1.858090e+11       1.32   0.572521
# 3      1.42        6.156968e+10       3.65   0.002686
# 4    627.24        1.347868e+08    1369.99   0.039818
#
#                last_updated
# 0  2026-04-17T18:33:57.798Z
# 1  2026-04-17T18:33:57.888Z
# 2  2026-04-17T18:33:57.842Z
# 3  2026-04-17T18:33:57.495Z
# 4  2026-04-17T18:33:58.044Z

# %%
df["last_updated"] = pd.to_datetime(df["last_updated"])

# %%
df = df.dropna()

# %%
df.dtypes
# Out:
# id                                             str
# symbol                                         str
# name                                           str
# current_price                              float64
# market_cap                                   int64
# market_cap_rank                              int64
# total_volume                               float64
# price_change_percentage_24h                float64
# high_24h                                   float64
# low_24h                                    float64
# circulating_supply                         float64
# ath                                        float64
# atl                                        float64
# last_updated                   datetime64[us, UTC]
# dtype: object

# %%
df.head()
# Out:
#             id symbol      name  current_price     market_cap  \
# 0      bitcoin    btc   Bitcoin       77224.00  1545460597452
# 1     ethereum    eth  Ethereum        2423.59   292370944641
# 2       tether   usdt    Tether           1.00   185873878309
# 3       ripple    xrp       XRP           1.48    91086540096
# 4  binancecoin    bnb       BNB         639.94    86224049098
#
#    market_cap_rank  total_volume  price_change_percentage_24h  high_24h  \
# 0                1  5.974516e+10                      3.76870  78240.00
# 1                2  2.519844e+10                      4.10618   2462.81
# 2                3  9.925832e+10                      0.01563      1.00
# 3                4  4.476654e+09                      3.04220      1.51
# 4                5  1.515209e+09                      1.49161    645.76
#
#     low_24h  circulating_supply        ath        atl  \
# 0  74419.00        2.001717e+07  126080.00  67.810000
# 1   2319.42        1.206909e+08    4946.05   0.432979
# 2      1.00        1.858090e+11       1.32   0.572521
# 3      1.42        6.156968e+10       3.65   0.002686
# 4    627.24        1.347868e+08    1369.99   0.039818
#
#                       last_updated
# 0 2026-04-17 18:33:57.798000+00:00
# 1 2026-04-17 18:33:57.888000+00:00
# 2 2026-04-17 18:33:57.842000+00:00
# 3 2026-04-17 18:33:57.495000+00:00
# 4 2026-04-17 18:33:58.044000+00:00

# %%
df.shape
# Out:
# (297, 14)

# %%
from datetime import datetime
from pathlib import Path




path = Path(f"../../parquet/data.parquet")
path.parent.mkdir(parents=True, exist_ok=True)
df.to_parquet(path)

# %%
from pathlib import Path
print(Path(__file__).resolve())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 2
#       1 from pathlib import Path
# ----> 2 print(Path(__file__).resolve())
#
# NameError: name '__file__' is not defined

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df.isna().sum()
# Out:
# id                             0
# symbol                         0
# name                           0
# current_price                  0
# market_cap                     0
# market_cap_rank                0
# total_volume                   0
# price_change_percentage_24h    0
# high_24h                       0
# low_24h                        0
# circulating_supply             0
# ath                            0
# atl                            0
# last_updated                   0
# dtype: int64
